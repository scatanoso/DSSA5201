# %%
import tweepy
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener
import sys
import json
import time
from textwrap import TextWrapper
from datetime import datetime
from elasticsearch import Elasticsearch

consumer_key = "iTNe4q1q1ihcgx5o93nbD2TCX"
consumer_secret = "QnbpybyBjOMjHwaWSROMssb8C9LHFpXTer05uZCE3pf2HdFqek"
access_token = "159489761-DVDyyfvD3hVEFhLLbQ7Sj9zSldw6hemNG3X6l9ZM"
access_token_secret = "FkhCAEW6daLOoQ8AZUX2DYHXYUsLuB6r75dZQ3UHEtJmr"

auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_token_secret)

ES_HOST = {"host" : "localhost", "port" : 9200}
es = Elasticsearch(hosts = [ES_HOST])


class StreamListener(tweepy.StreamListener):
    
        print('Starting StreamListener')
        status_wrapper = TextWrapper(width=60, initial_indent='    ', subsequent_indent='    ')

        def on_error(self, status):
                    print(status)
                    
        def on_status(self, status):
                try:
                        print ("n%s %s" % (status.author.screen_name, status.created_at))
                        json_data = status._json
                        print(json_data['text'])
                        print(json_data['id'])
                        es.index(index="twitter_trump",
                                  doc_type="twitter_tweet",
                                  id=json_data['id'],
                                  body=json_data,
                                  ignore=400
                                 )                       
                except Exception as e:
                        print(e)
                        pass
       
        
print('Starting Receiving')
runtime = 1 #this is in seconds

streamer = tweepy.Stream(auth=auth, listener=StreamListener(), timeout=30)

streamer.filter(track=['Trump'], is_async=True)        
#streamer.userstream(None) if you want to query a user


print("sleeping")
time.sleep(runtime)
print("waking")
streamer.disconnect()

print ('Ending program')
# Out:
# Starting StreamListener
# Starting Receiving
# sleeping
# npepper55bs 2018-12-12 17:04:47
# I have worry about how bad this thing Trump could end !What if trump has a debt with Putin that could get us all ki… https://t.co/KhNLLdq1sD
# 1072900082645659649
# njh7468 2018-12-12 17:04:47
# RT @PeacefulConserv: This tweet didn't age well. https://t.co/b0ezE2YOQi
# 1072900082859679750
# nGFrumberson 2018-12-12 17:04:47
# RT @AriFleischer: Justice is based on investigating crimes and connecting them to people.  Here, we have a liberal, anti-Trump prosecutor m…
# 1072900083031531520
# nSirveaux1066 2018-12-12 17:04:48
# RT @KaraCalavera: Very few people in general have actually stood up to Trump to his face, at least in public. I can only think of four offh…
# 1072900083308474373
# nandrewgutin 2018-12-12 17:04:48
# Every President lies. Trump just lies worse.
# 1072900083157393408
# nwilliam4manu 2018-12-12 17:04:48
# @aldotcom Homegrown terrorist!   Just like here in USA.  Trump the idiot doesn’t get it.
# 1072900083786633216
# nhollywoodkc27 2018-12-12 17:04:48
# STORMY DANIELS ORDERED  TO PAY 300,000 TO TRUMP IN COURT !!!
# https://t.co/JLWNapGWXL
# 1072900083937669123
# nponytail122 2018-12-12 17:04:48
# RT @laureldavilacpa: Trump ignorance is pervasive. Not only is the #BorderWall something the American people don’t want to pay for - but it…
