# %%
from tweepy import Stream
from tweepy import OAuthHandler
from tweepy.streaming import StreamListener

ckey = "iTNe4q1q1ihcgx5o93nbD2TCX"
csecret ="QnbpybyBjOMjHwaWSROMssb8C9LHFpXTer05uZCE3pf2HdFqek"
atoken = "159489761-DVDyyfvD3hVEFhLLbQ7Sj9zSldw6hemNG3X6l9ZM"
asecret = "FkhCAEW6daLOoQ8AZUX2DYHXYUsLuB6r75dZQ3UHEtJmr"

class listener(StreamListener):
    def on_data(self, data):
        print(data)
        return True
    
    def on_error(self, status):
        print(status)
        
auth = OAuthHandler(ckey, csecret)
auth.set_access_token(atoken, asecret)
twitterStream = Stream(auth, listener())
twitterStream.filter(track=["fake"])
# Out:
# {"created_at":"Wed Dec 12 05:16:54 +0000 2018","id":1072721936285716480,"id_str":"1072721936285716480","text":"Add the fake ass crying and you\u2019ve got it all in a bag","source":"\u003ca href=\"http:\/\/twitter.com\/download\/iphone\" rel=\"nofollow\"\u003eTwitter for iPhone\u003c\/a\u003e","truncated":false,"in_reply_to_status_id":1072721875699032064,"in_reply_to_status_id_str":"1072721875699032064","in_reply_to_user_id":874984868941254658,"in_reply_to_user_id_str":"874984868941254658","in_reply_to_screen_name":"jo_xu__","user":{"id":874984868941254658,"id_str":"874984868941254658","name":"\uff61\uff65:*:\uff65\uff9f || jungkook feeds us well","screen_name":"jo_xu__","location":"uwu","url":null,"description":"[ fan account ] \/\/ i will soft block anyone who follows me because this account is literally spam and I\u2019m sparing you from the pain and my rants. pls forgive!","translator_type":"none","protected":false,"verified":false,"followers_count":3,"friends_count":247,"listed_
# ...
